# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
naive_adaption_path = "/home/weixinli/time-series-domain-adaptation/train_related/f-gan/naive_adaption/"
unlabeled_f_div = np.load(naive_adaption_path+"unlabeled_f_div.npy")
labeled_f_div = np.load(naive_adaption_path+"labeled_f_div.npy")
epochs = np.load(naive_adaption_path+"epochs.npy")

# %%
plt.plot(epochs, unlabeled_f_div)
plt.title('KL-div of unlabeled data, naive adapatation')
# Out:
# Text(0.5, 1.0, 'KL-div of unlabeled data, naive adapatation')

# %%
plt.plot(epochs, labeled_f_div)
plt.title('KL-div of unlabeled data, naive adapatation')
# Out:
# Text(0.5, 1.0, 'KL-div of unlabeled data, naive adapatation')

# %%
prob_classifier_path = '/home/weixinli/time-series-domain-adaptation/train_related/f-gan/prob_classifier/'
unlabeled_f_div = np.load(prob_classifier_path+"unlabeled_f_div.npy")
labeled_f_div = np.load(prob_classifier_path+"labeled_f_div.npy")
epochs = np.load(prob_classifier_path+"epochs.npy")

# %%
plt.plot(epochs, unlabeled_f_div)
plt.title('KL-div of unlabeled data, prob. classifier')
# Out:
# Text(0.5, 1.0, 'KL-div of unlabeled data, prob. classifier')

# %%
plt.plot(epochs, labeled_f_div)
plt.title('KL-div of labeled data, prob. classifier')
# Out:
# Text(0.5, 1.0, 'KL-div of labeled data, prob. classifier')
